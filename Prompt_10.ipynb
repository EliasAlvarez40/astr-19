# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nums = np.random.geometric(p=0.25, size=1000)

# %%
plt.hist(nums,bins=100)
plt.xlabel("T to complete Midterm")
plt.ylabel("Grade")
plt.savefig("Prompt10.pdf")
plt.show()
