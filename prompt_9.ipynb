# %% [markdown]
# Elias Alvarez
# ## Prompt 9

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nums = np.random.uniform(0,1,1000)

# %%
plt.hist(nums, bins=100)
plt.xlabel('T it takes to complete Vault Of Glass')
plt.ylabel('Vex Mythoclast drop chance')
plt.savefig("prompt9.pdf", dpi=300, bbox_inches='tight')
plt.show()
